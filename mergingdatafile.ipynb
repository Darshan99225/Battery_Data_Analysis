# %%
import pandas as pd

# %%
metadata_df = pd.read_csv("metadata.csv")
metadata_df
# Out:
#            type                                         start_time  \
# 0     discharge  [2010.       7.      21.      15.       0.    ...
# 1     impedance  [2010.       7.      21.      16.      53.    ...
# 2        charge  [2010.       7.      21.      17.      25.    ...
# 3     impedance                    [2010    7   21   20   31    5]
# 4     discharge  [2.0100e+03 7.0000e+00 2.1000e+01 2.1000e+01 2...
# ...         ...                                                ...
# 7560  impedance  [2010.       9.      30.       7.      36.    ...
# 7561  discharge  [2010.       9.      30.       8.       8.    ...
# 7562     charge  [2010.      9.     30.      8.     48.     54.25]
# 7563  discharge  [2010.       9.      30.      11.      50.    ...
# 7564     charge  [2010.       9.      30.      12.      31.    ...
#
#       ambient_temperature battery_id  test_id   uid   filename  \
# 0                       4      B0047        0     1  00001.csv
# ...

# %%
file_name = metadata_df.loc[metadata_df['type']=='discharge',"filename"].values[0]
file_data = pd.read_csv("data/"+file_name)
file_data = pd.DataFrame(columns=file_data.columns.values)
file_data = file_data.reindex(columns = file_data.columns.tolist() + ['battery_id'])
file_data
# Out:
# Empty DataFrame
# Columns: [Voltage_measured, Current_measured, Temperature_measured, Current_load, Voltage_load, Time, battery_id]
# Index: []

# %%
file_name = metadata_df.loc[metadata_df['type']=='discharge',"filename"].values[0]
file_data = pd.read_csv("data/"+file_name)
file_data = file_data.reindex(columns = file_data.columns.tolist() + ['battery_id'])
file_data.to_csv("discharge.csv",mode='a')
for id, rows in metadata_df.iterrows():
    if(rows["type"]=="discharge"):
        file_data = pd.read_csv("data/"+rows["filename"])
        file_data["battery_id"] = rows["battery_id"]
        file_data = file_data.rename(columns=file_data.iloc[0]).drop(file_data.index[0])
        file_data.to_csv("discharge.csv",mode='a')

# %%
#CSV for charge 
file_name = metadata_df.loc[metadata_df['type']=='charge',"filename"].values[0]
file_data = pd.read_csv("data/"+file_name)
file_data = file_data.reindex(columns = file_data.columns.tolist() + ['battery_id'])
file_data.to_csv("charge.csv",mode='a')
for id, rows in metadata_df.iterrows():
    if(rows["type"]=="charge"):
        file_data = pd.read_csv("data/"+rows["filename"])
        file_data["battery_id"] = rows["battery_id"]
        file_data = file_data.rename(columns=file_data.iloc[0]).drop(file_data.index[0])
        file_data.to_csv("charge.csv",mode='a')

# %%
file_name = metadata_df.loc[metadata_df['type']=='impedance',"filename"].values[0]
file_data = pd.read_csv("data/"+file_name)
file_data = file_data.reindex(columns = file_data.columns.tolist() + ['battery_id'])
file_data.to_csv("impedance.csv",mode='a')
for id, rows in metadata_df.iterrows():
    if(rows["type"]=="impedance"):
        file_data = pd.read_csv("data/"+rows["filename"])
        file_data["battery_id"] = rows["battery_id"]
        file_data = file_data.rename(columns=file_data.iloc[0]).drop(file_data.index[0])
        file_data.to_csv("impedance.csv",mode='a')
